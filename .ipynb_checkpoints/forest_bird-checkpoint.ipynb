# %% [markdown]
# ### Imports

# %%
from fastcore.all import *
import re
import time
from fastdownload import download_url
import cv2 as cv
from duckduckgo_search import ddg_images
from fastai.vision.all import download_images, resize_images, get_image_files, verify_images, ImageDataLoaders
from time import sleep

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from torchvision import datasets, models
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from torch.utils.data import DataLoader
from skimage import io, transform
import matplotlib.image as mpimg
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Download Images

# %%
def search_images(term, max_images=200):
    print(f"Searching for '{term}'")
    return L(ddg_images(term, max_results=max_images)).itemgot('image')

# %%
searches = 'forest','bird'
path = Path('bird_or_not')

# %%
def download_all_images(searches, path):
    for o in searches:
        dest = (path/o)
        dest.mkdir(exist_ok=True, parents=True)
        download_images(dest, urls=search_images(f'{o} photo'))
        sleep(10)  # Pause between searches to avoid over-loading server
        download_images(dest, urls=search_images(f'{o} sun photo'))
        sleep(10)
        download_images(dest, urls=search_images(f'{o} shade photo'))
        sleep(10)
        resize_images(path/o, max_size=400, dest=path/o)


download_all_images(searches, path)

# %%
failed = verify_images(get_image_files(path))
failed.map(Path.unlink)
len(failed)
# Out:
# 0

# %%
failed_1 = verify_images(get_image_files(path))
failed_1.map(Path.unlink)
len(failed_1)
# Out:
# 0

# %% [markdown]
# ### Creating Dataset

# %%
class ForestBirdDataset:
    def __init__(self, images, labels, transforms=None):
        self.images = images
        self.transforms = transforms
        self.labels = labels
        self.classes = {'bird' : 0, 'forest' : 1}

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx]
        label = self.classes[self.labels[idx]]
        img = mpimg.imread(str(image))
        if self.transforms:
            img = self.transforms(img)
        return img, label

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
    transforms.Resize((256, 256))
    # transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ]
)

# %%
def get_label(image):
    return image.parent.name

X= get_image_files(path)
y = [get_label(img) for img in X]

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.10, random_state=42)

# %%
# y_train

# %%
traindataset = ForestBirdDataset(X_train, y_train, transforms=transform)
validdataset = ForestBirdDataset(X_valid, y_valid, transforms=transform)

# %%
# traindataset[1][0].shape
# Out:
# torch.Size([3, 256, 256])

# %%
len(os.listdir(path/'forest'))
# Out:
# 574

# %%
plt.imshow(traindataset[1][0].permute(1, 2, 0))

# %%
img = mpimg.imread('bird_or_not/bird/0890a669-895a-4de0-97d4-f1ecbfda2cc9.jpg')
plt.imshow(img)
plt.show()

# %%
plt.imshow(validdataset[0][0].permute(1, 2, 0))
plt.show()

# %%
batch_size = 4
learning_rate = 0.01
num_epochs = 10

# %%
train_dataloader = DataLoader(traindataset, batch_size=batch_size, shuffle=True)
valid_dataloader = DataLoader(validdataset, batch_size=batch_size, shuffle=True)

# %%
# for i, (images, labels) in enumerate(train_dataloader):
#     print(images.shape)

# %%
features, labels = next(iter(train_dataloader))

# %%
features[0].shape
# Out:
# torch.Size([3, 256, 256])

# %%
conv1 = nn.Conv2d(3, 6, 5)
pool = nn.MaxPool2d(2,2)
conv2 = nn.Conv2d(6, 16, 5)

x = conv1(features[0])
print(x.shape)
x = pool(x)
print(x.shape)
x = conv2(x)
print(x.shape)
x = pool(x)
print(x.shape)
# # fc1 = nn.Linear(16*)
x = (F.relu(x))
print(x.shape)
x = x.view(-1, 16*61*61)
print(x.shape)
# Out:
# torch.Size([6, 252, 252])
# torch.Size([6, 126, 126])
# torch.Size([16, 122, 122])
# torch.Size([16, 61, 61])
# torch.Size([16, 61, 61])
# torch.Size([1, 59536])

# %% [markdown]
# ### Creating Model

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
class ForestBirdConv(nn.Module):
    def __init__(self) -> None:
        super(ForestBirdConv, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2,2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16*61*61, 400)
        self.fc2 = nn.Linear(400, 200)
        self.fc3 = nn.Linear(200, 100)
        self.fc4 = nn.Linear(100, 50)
        self.fc5 = nn.Linear(50, 2)
    
    def forward(self, x):
        x = F.relu(self.pool(self.conv1(x)))
        x = F.relu(self.pool(self.conv2(x)))
        x = x.view(-1, 16*61*61)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.relu(self.fc4(x))
        x = (self.fc5(x))
        return x

# %%
model = ForestBirdConv().to(device)

# %%
model
# Out:
# ForestBirdConv(
#   (conv1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=59536, out_features=400, bias=True)
#   (fc2): Linear(in_features=400, out_features=200, bias=True)
#   (fc3): Linear(in_features=200, out_features=100, bias=True)
#   (fc4): Linear(in_features=100, out_features=50, bias=True)
#   (fc5): Linear(in_features=50, out_features=2, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
step_lr_schedular = torch.optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)

n_total_steps = len(train_dataloader)
for epoch in tqdm(range(num_epochs)):
    for i, (images, labels) in enumerate(train_dataloader):
        images = images.to(device)
        labels = labels.to(device)


        ##forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)


        ##Backward
        optimizer.zero_grad()
        loss.backward()
    

        if (i+1) % 100 == 0:
            print(f"Epoch {epoch+1}/{num_epochs}, Step {i+1}/{n_total_steps}, Loss : {loss.item():.4f}")
    step_lr_schedular.step()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch 1/10, Step 100/256, Loss : 0.6934
# Epoch 1/10, Step 200/256, Loss : 0.6921
# /home/shubham/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:131: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# Epoch 2/10, Step 100/256, Loss : 0.6937
# Epoch 2/10, Step 200/256, Loss : 0.6933
# Epoch 3/10, Step 100/256, Loss : 0.6930
# Epoch 3/10, Step 200/256, Loss : 0.6940
# Epoch 4/10, Step 100/256, Loss : 0.6927
# Epoch 4/10, Step 200/256, Loss : 0.6932
# Epoch 5/10, Step 100/256, Loss : 0.6933
# ...

# %%
# !ls
# Out:
# bird_or_not  forest_bird.ipynb	index_1.jpeg  index.jpeg

# %%
img = mpimg.imread("index.jpeg")

# %%
new_img = transform(img)

# %%
outputs = model(new_img.to(device))

# %%
_, predicted = torch.max(outputs.data, 1)

# %%
predicted
# Out:
# tensor([0], device='cuda:0')

# %%
plt.imshow(img)
plt.show()

# %% [markdown]
# ### Check Accuracy by Validation dataset

# %%
with model.zero_grad():
    for images, labels in valid_dataloader:
        images = images.to(device)

# %% [markdown]
# ### Transfer Learning

# %%
model = models.resnet18()

# %%
num_ftrs = model.fc.in_features

# %%
model.fc = nn.Linear(num_ftrs, 2)
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %%
###schedular for changing learning rate

step_lr_schedular = torch.optim.lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)   #this means every 7 epochs learning rate is multiplied by gamma

# %%
n_total_steps = len(train_dataloader)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_dataloader):
        images = images
        labels = labels


        ##forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)


        ##Backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        if (i+1) % 100 == 0:
            print(f"Epoch {epoch+1}/{num_epochs}, Step {i+1}/{n_total_steps}, Loss : {loss.item():.4f}")
    step_lr_schedular.step()
